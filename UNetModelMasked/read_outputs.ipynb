# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
losses = {'training_loss': np.load('losses/loss.npy'), 'val_loss': np.load('losses/val_loss.npy')}

# %%
losses['training_loss']
# Out:
# array([0.47352973])

# %%
pred_fields = [np.load(f'output_products/pred_field_{i:03d}.npy') for i in range(10)]
obs_fields = [np.load(f'obs_data/halo_over_density_redshift_space_128_CIC_{i:03d}_group_tab_002.npy') for i in range(10)]

# %%
plt.imshow(pred_fields[0][:, :, 32], vmin=-1, vmax=1)

# %%
plt.imshow(obs_fields[0][:, :, 32], vmin=-1, vmax=1)
